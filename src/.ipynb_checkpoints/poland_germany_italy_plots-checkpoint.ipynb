# %%
import pandas as pd
import datetime
import csv
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/time_series_19-covid-Confirmed.csv')

# %%
df
# Out:
#      Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0               NaN       Thailand  15.0000  101.0000        2        3
# 1               NaN          Japan  36.0000  138.0000        2        1
# 2               NaN      Singapore   1.2833  103.8333        0        1
# 3               NaN          Nepal  28.1667   84.2500        0        0
# 4               NaN       Malaysia   2.5000  112.5000        0        0
# ..              ...            ...      ...       ...      ...      ...
# 399     Socorro, NM             US  33.8837 -106.7235        0        0
# 400  Bernalillo, NM             US  35.0178 -106.6291        0        0
# 401     Oakland, MI             US  42.5922  -83.3362        0        0
# 402       Wayne, MI             US  42.2791  -83.3362        0        0
# 403  New Castle, DE             US  39.5393  -75.6674        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/2/20  3/3/20  3/4/20  3/5/20  \
# 0          5        7        8        8  ...      43      43      43      47
# 1          2        2        4        4  ...     274     293     331     360
# 2          3        3        4        5  ...     108     110     110     117
# 3          0        1        1        1  ...       1       1       1       1
# 4          0        3        4        4  ...      29      36      50      50
# ..       ...      ...      ...      ...  ...     ...     ...     ...     ...
# 399        0        0        0        0  ...       0       0       0       0
# 400        0        0        0        0  ...       0       0       0       0
# 401        0        0        0        0  ...       0       0       0       0
# 402        0        0        0        0  ...       0       0       0       0
# 403        0        0        0        0  ...       0       0       0       0
#
#      3/6/20  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# 0        48      50      50      50       53       59
# 1       420     461     502     511      581      639
# 2       130     138     150     150      160      178
# 3         1       1       1       1        1        1
# 4        83      93      99     117      129      149
# ..      ...     ...     ...     ...      ...      ...
# 399       0       0       0       0        0        0
# 400       0       0       0       0        0        0
# 401       0       0       0       0        0        0
# 402       0       0       0       0        0        0
# 403       0       0       0       0        0        0
#
# [404 rows x 54 columns]

# %%
columns = ['Province/State', 'Lat', 'Long']
df.drop(columns, axis=1, inplace=True)

# %%
df
# Out:
#     Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0         Thailand        2        3        5        7        8        8
# 1            Japan        2        1        2        2        4        4
# 2        Singapore        0        1        3        3        4        5
# 3            Nepal        0        0        0        1        1        1
# 4         Malaysia        0        0        0        3        4        4
# ..             ...      ...      ...      ...      ...      ...      ...
# 399             US        0        0        0        0        0        0
# 400             US        0        0        0        0        0        0
# 401             US        0        0        0        0        0        0
# 402             US        0        0        0        0        0        0
# 403             US        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  3/2/20  3/3/20  3/4/20  3/5/20  3/6/20  \
# 0         14       14       14  ...      43      43      43      47      48
# 1          7        7       11  ...     274     293     331     360     420
# 2          7        7       10  ...     108     110     110     117     130
# 3          1        1        1  ...       1       1       1       1       1
# 4          4        7        8  ...      29      36      50      50      83
# ..       ...      ...      ...  ...     ...     ...     ...     ...     ...
# 399        0        0        0  ...       0       0       0       0       0
# 400        0        0        0  ...       0       0       0       0       0
# 401        0        0        0  ...       0       0       0       0       0
# 402        0        0        0  ...       0       0       0       0       0
# 403        0        0        0  ...       0       0       0       0       0
#
#      3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# 0        50      50      50       53       59
# 1       461     502     511      581      639
# 2       138     150     150      160      178
# 3         1       1       1        1        1
# 4        93      99     117      129      149
# ..      ...     ...     ...      ...      ...
# 399       0       0       0        0        0
# 400       0       0       0        0        0
# 401       0       0       0        0        0
# 402       0       0       0        0        0
# 403       0       0       0        0        0
#
# [404 rows x 51 columns]

# %%
selected_countries = ['Poland', 'Germany', 'Italy']
poland_and_neighbours = df[df['Country/Region'].isin(selected_countries)]

# %%
poland_and_neighbours
# Out:
#    Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 11        Germany        0        0        0        0        0        1
# 16          Italy        0        0        0        0        0        0
# 74         Poland        0        0        0        0        0        0
#
#     1/28/20  1/29/20  1/30/20  ...  3/2/20  3/3/20  3/4/20  3/5/20  3/6/20  \
# 11        4        4        4  ...     159     196     262     482     670
# 16        0        0        0  ...    2036    2502    3089    3858    4636
# 74        0        0        0  ...       0       0       1       1       5
#
#     3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# 11     799    1040    1176     1457     1908
# 16    5883    7375    9172    10149    12462
# 74       5      11      16       22       31
#
# [3 rows x 51 columns]

# %% [markdown]
# ### Removing columns containing zeros
# - `germany_non_zero` - removed all columns that contain all zeros
# - `poland_non_zero` - removed all columns that containt any zero

# %%
germany_non_zero = poland_and_neighbours.loc[:, (poland_and_neighbours != 0).any()]
poland_non_zero = poland_and_neighbours.loc[:, (poland_and_neighbours != 0).all()]

# %%
germany_non_zero
# Out:
#    Country/Region  1/27/20  1/28/20  1/29/20  1/30/20  1/31/20  2/1/20  \
# 11        Germany        1        4        4        4        5       8
# 16          Italy        0        0        0        0        2       2
# 74         Poland        0        0        0        0        0       0
#
#     2/2/20  2/3/20  2/4/20  ...  3/2/20  3/3/20  3/4/20  3/5/20  3/6/20  \
# 11      10      12      12  ...     159     196     262     482     670
# 16       2       2       2  ...    2036    2502    3089    3858    4636
# 74       0       0       0  ...       0       0       1       1       5
#
#     3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# 11     799    1040    1176     1457     1908
# 16    5883    7375    9172    10149    12462
# 74       5      11      16       22       31
#
# [3 rows x 46 columns]

# %%
poland_non_zero
# Out:
#    Country/Region  3/4/20  3/5/20  3/6/20  3/7/20  3/8/20  3/9/20  3/10/20  \
# 11        Germany     262     482     670     799    1040    1176     1457
# 16          Italy    3089    3858    4636    5883    7375    9172    10149
# 74         Poland       1       1       5       5      11      16       22
#
#     3/11/20
# 11     1908
# 16    12462
# 74       31

# %% [markdown]
# ### Selecting only Poland row and leaving only the dates columns for plotting.

# %%
poland = poland_non_zero[poland_non_zero['Country/Region'] == 'Poland']
poland = poland.loc[:, poland.columns != 'Country/Region']
poland
# Out:
#     3/4/20  3/5/20  3/6/20  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# 74       1       1       5       5      11      16       22       31

# %%
plt.plot(poland.columns, poland.iloc[0, :], linestyle='dashed', marker='o')
plt.show()

# %% [markdown]
# ### Similarly selecting the data for Germany and Italy

# %%
italy = poland_non_zero[poland_non_zero['Country/Region'] == 'Italy']
italy = italy.loc[:, italy.columns != 'Country/Region']
italy
# Out:
#     3/4/20  3/5/20  3/6/20  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# 16    3089    3858    4636    5883    7375    9172    10149    12462

# %%
germany = poland_non_zero[poland_non_zero['Country/Region'] == 'Germany']
germany = germany.loc[:, germany.columns != 'Country/Region']
germany
# Out:
#     3/4/20  3/5/20  3/6/20  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# 11     262     482     670     799    1040    1176     1457     1908

# %%
plt.plot(poland.columns, poland.iloc[0, :], linestyle='dashed', marker='o')
plt.plot(germany.columns, germany.iloc[0, :], linestyle='dashed', marker='o')
#plt.plot(italy.columns, italy.iloc[0, :], linestyle='dashed', marker='o')
plt.show()
